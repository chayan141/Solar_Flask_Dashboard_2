# %%
import pandas as pd

# %%
df = pd.read_excel('95 MW Dhuvaran DGR.xlsx',sheet_name='DGR')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8675 entries, 0 to 8674
# Data columns (total 41 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Month                                      8675 non-null   int64
#  1   Date                                       8675 non-null   datetime64[ns]
#  2   Start time                                 8675 non-null   object
#  3   End Time                                   8675 non-null   object
#  4   DC Capacity                                8675 non-null   int64
#  5   GII                                        8675 non-null   float64
#  6   GHI                                        8675 non-null   float64
#  7   Avg. Ambient Temp                          8675 non-null   float64
#  8   Avg. Module Temp                           8675 non-null   float64
#  9   Total INV Gen. in KWh                      8675 non-null   float64
# ...

# %%
from datetime import datetime as dt

# %%
df['Date']
# Out:
# 0      2023-02-01
# 1      2023-02-01
# 2      2023-02-01
# 3      2023-02-01
# 4      2023-02-01
#           ...
# 8670   2024-01-20
# 8671   2024-01-20
# 8672   2024-01-20
# 8673   2024-01-20
# 8674   2024-01-20
# Name: Date, Length: 8675, dtype: datetime64[ns]

# %%
dt.strptime('2024-01-20','%Y-%m-%d').date()
# Out:
# datetime.date(2024, 1, 20)

# %%
df1 = df.groupby(['Date','Inv Name']).agg({'Inverter PR%':'mean','Inv Gen in MWh':'sum'}).reset_index()

# %%
df1
# Out:
#            Date Inv Name  Inverter PR%  Inv Gen in MWh
# 0    2023-02-01  INV-01A      0.807819          18.908
# 1    2023-02-01  INV-02A      0.772922          18.383
# 2    2023-02-01  INV-02B      0.751533          18.158
# 3    2023-02-01  INV-03A      0.808148          17.136
# 4    2023-02-01  INV-03B      0.814321          18.804
# ...         ...      ...           ...             ...
# 8645 2024-01-20  INV-11B      0.802837          18.125
# 8646 2024-01-20  INV-12A      0.794113          17.018
# 8647 2024-01-20  INV-12B      0.795535          17.869
# 8648 2024-01-20  INV-13A      0.837651          18.287
# 8649 2024-01-20  INV-13B      0.794432          17.389
#
# [8650 rows x 4 columns]

# %%
dfp = (
        df.groupby([df["Date"], df["Inv Name"]])
        .size()
        .unstack("Inv Name", 0)
        .assign(Events=lambda d: d.sum(axis=1))
    )

# %%
dfp
# Out:
# Inv Name    INV-01A  INV-02A  INV-02B  INV-03A  INV-03B  INV-04A  INV-04B  \
# Date
# 2023-02-01        1        1        1        1        1        1        1
# 2023-02-02        1        1        1        1        1        1        1
# 2023-02-03        1        1        1        1        1        1        1
# 2023-02-04        1        1        1        1        1        1        1
# 2023-02-05        1        1        1        1        1        1        1
# ...             ...      ...      ...      ...      ...      ...      ...
# 2024-01-16        1        1        1        1        1        1        1
# 2024-01-17        1        1        1        1        1        1        1
# 2024-01-18        1        1        1        1        1        1        1
# 2024-01-19        1        1        1        1        1        1        1
# 2024-01-20        1        1        1        1        1        1        1
#
# Inv Name    INV-05A  INV-05B  INV-06A  ...  INV-09B  INV-10A  INV-10B  \
# ...
